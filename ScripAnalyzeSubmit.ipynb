# %% [markdown]
# <a href="https://colab.research.google.com/github/JxCorona/CIS3120/blob/main/ScripAnalyzeSubmit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("What is your name?")
print(f"Hello, {name}!")
print("This weather is crazy huh??")
# Out:
# What is your name?jo
# Hello, jo!
# This weather is crazy huh??
